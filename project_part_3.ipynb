# %% [markdown]
# ## Introduction

# %% [markdown]
# The optic nerve sends visual information from the eye to the brain and has limited regenerative ability after damage. One way to promote regeneration is by targeting phosphatase and tensin homolog (PTEN). This study aimed to measure lipid concentrations in mice optic nerve crush samples following AAV-PLAP (control) or AAV-CRE (KO) injections to test if PTEN promotes regeneration.

# %% [markdown]
# ## Part 2: Relate research questions, data, and figures

# %% [markdown]
# ### Section 1: Data & Research Questions
# The following is a link to the study: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7797512/.
# The central nervous system controls many of the human body’s functions. One important part of
# the system includes the optic nerve that acts as a communication method to send visual images
# from the eye to the brain: an integral part of eyesight. The optic nerve can regenerate after
# damage to the nerve, however, the ability to regenerate is limited.
#
# The observations in the data set are the different samples that were collected. There are 74
# observations or different samples that were collected. This study was done on mice. One possible
# way to promote regeneration of the optic nerve is through phosphatase and ten homolog (PTEN)
# deletion. To test the hypothesis, mice were injected with either control (AAV-PLAP) or AAV-Cre
# (KO).  Samples of the optic nerve crush were collected, and lipids were extracted and analyzed
# by liquid chromatography- mass spectrometry to find the concentration of lipids in those
# samples. The features are the type of lipids found in each of the samples. There is only one
# feature. This feature allows for the measurement of lipid concentration in each of the samples, or
# observations. The lipid concentrations are the only data collected in this experiment.
#
# The purpose of this study was to explore optic nerve regeneration and how to promote
# regeneration after an injury. The hypothesis was that the deletion of PTEN promotes regeneration
# of the optic nerve. Through the different lipid concentration collected from the samples, the
# concentrations for the control can be compared with the experimental group to determine if there
# are significant changes in lipids. If there are changes in the lipid concentrations, it can support
# that regeneration could be promoted by PTEN deletion.
#
# One other research question that could be asked using this data is which lipids are affected the
# most and which lipids are affected the least by the PTEN deletion. The data would be useful to
# compare the differences in lipid concentrations and order the lipids by which ones are affected
# the most and the least.

# %% [markdown]
# ### Section 2: Data & Research Questions

# %% [markdown]
# ![image.png](attachment:7d6c56c3-4feb-4d6e-a73a-94091654a55d.png)
# Figure 1. Plot of variable importance in projection (VIP) scores
#
# The plots in the first figure was generated using the same lipid data as mentioned in section one.
# The x – axis shows the VIP scores for each of the lipids displayed on the y – axis. Plot A, on the
# left, displays the scores for the control groups at days 0, 7, and 14. Plot B, on the right, displays
# the scores for the experiment groups with PTEN deletion for days 0, 7, and 14.
#
# The authors chose to include this particular figure in the paper to show the difference in lipids
# with PTEN deletion. It can be observed from the plots that with the PTEN deletion, there are
# changes in the lipids which could support the hypothesis that PTEN deletion promotes optic
# nerve regeneration. It can be concluded that PTEN deletion has some effect on regeneration
# which is shown through the differences in the lipids when comparing the control to the
# experiment group.

# %% [markdown]
# ![image.png](attachment:6c2a2d04-9f29-4a39-8926-6c2e82db0226.png)
#
# Figure 2. Heatmap of the regeneration distances based on the changes in lipids
#
# The heatmap in this figure displays which lipid influenced further regeneration of the optic
# nerve. The values represented by the colors on the heatmap are the distances of the optic nerve
# regeneration. The row with the different colors at the very top represents the different classes of
# controls at day 0, 7, and 14 and the experiment groups at 0, 7, and 14 days. On the right is the
# labeled rows with the different lipids. The darker reds represent the greatest positive change in
# distance and the darker blues represent the least change in distance of regeneration.
#
# The authors chose to include this figure in the paper to show if the PTEN deletion affected how
# much regeneration occurred and which lipids were affected the most. Through this heatmap, it
# can be observed that with the PTEN deletion some lipids had a very big change compared to
# others and had the greatest distance difference in regeneration. This supports the hypothesis and
# it can be concluded that PTEN deletion promoted regeneration because of the significant change
# in the distance and lipids.

# %% [markdown]
# One other figure that would be helpful to understand the lipid dataset would be a histogram. The
# x – axis would be the different lipid concentration ranges and the y – axis would be the count of
# how many lipids are within those ranges. The histogram would help to tell how many lipids have
# a significant change in concentration by looking at how many lipids are part of the higher value
# bins towards the right of the x – axis.

# %% [markdown]
# ### Section 3: Data & Research Questions

# %% [markdown]
# Here is a link to the data file: mmc1 (2).xlsx.
#
# There are 1085 rows and 74 columns in the dataset. The file relates to the paper through the lipid
# concentrations that are observed for each of the optic nerve samples. The data also contains the
# different lipids that were observed. Using the lipid data the control and experiment groups can be
# compared to see if PTEN deletion has any effect on optic nerve regeneration. The format of the
# data is different lipids in the first column and then other columns show one sample each. The
# rows represent the values for the lipid labeled for that row.

# %% [markdown]
# ## Part 3: Data Cleaning and Exploration

# %% [markdown]
# ### 3.1 Load and Clean Data

# %% [markdown]
# Downloading & Loading Data:
#
# Here is a link to the article: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7797512/
#
# At the bottom of the article, there is a supplementary section that includes the data that can be downloaded by clicking on the xlsx link.
#
# Once the xlsx file is downloaded, the file can be opened in excel and downloaded as a csv file. The file was renamed 'lipids' and uploaded into JupyterLab.

# %%
# import pandas 
import pandas as pd
# read in lipids data file
lipids = pd.read_csv("lipids.csv", index_col = 0)

# %%
# display the first 5 rows of the dataframe
lipids.head(5)
# Out:
#                      C0_01      C0_02      C0_03     C0_04      C0_05  \
# LipidMolec
# PG(18:1D7_15:0)  12.658228  10.152284  11.204482  9.259259  25.157233
# AcCa(20:4)        0.114122   0.041171   0.222181  0.520064   0.201793
# AcCa(12:0)        0.032140   0.027043   0.055414  0.135732   0.102917
# AcCa(14:0)        0.223067   0.150191   0.635933  1.135621   0.771662
# AcCa(14:1)        0.000000   0.020812   0.062591  0.036512   0.119915
#
#                      C0_06     C0_07      C0_08      C0_09      C0_10  ...  \
# LipidMolec                                                             ...
# PG(18:1D7_15:0)  11.730205  7.575758  11.049724  13.468013  11.764706  ...
# AcCa(20:4)        1.187269  0.173761   0.149528   0.233576   0.086831  ...
# AcCa(12:0)        0.238251  0.031590   0.048294   0.013949   0.042019  ...
# AcCa(14:0)        3.641362  0.513428   0.670949   0.594170   0.464055  ...
# AcCa(14:1)        0.065811  0.133833   0.122518   0.078735   0.074497  ...
#
# ...

# %% [markdown]
# To do the describe functions in 3.2, the data frame had to be transposed because without transposing the features would be the rows and the observations would be the columns.

# %%
# import numpy 
import numpy as np
# transpose the dataframe
lipids = lipids.transpose()
# convert the transposed lipids into a dataframe
lipids = pd.DataFrame(lipids)
# print the first 5 rows of the transposed dataframe
lipids.head(5)
# Out:
# LipidMolec  PG(18:1D7_15:0)  AcCa(20:4)  AcCa(12:0)  AcCa(14:0)  AcCa(14:1)  \
# C0_01             12.658228    0.114122    0.032140    0.223067    0.000000
# C0_02             10.152284    0.041171    0.027043    0.150191    0.020812
# C0_03             11.204482    0.222181    0.055414    0.635933    0.062591
# C0_04              9.259259    0.520064    0.135732    1.135621    0.036512
# C0_05             25.157233    0.201793    0.102917    0.771662    0.119915
#
# LipidMolec  AcCa(16:0)  AcCa(16:1)  AcCa(17:0)  AcCa(18:0)  AcCa(18:1)  ...  \
# C0_01         1.406457    0.202392    0.005607    0.647983    1.167924  ...
# C0_02         0.853258    0.072167    0.003749    0.325008    1.123956  ...
# C0_03         3.164966    0.363885    0.017842    1.115355    2.832484  ...
# C0_04         4.333018    0.560318    0.019225    2.418203    5.265536  ...
# C0_05         4.016267    0.534245    0.102647    2.043967    4.269698  ...
#
# ...

# %% [markdown]
# ### 3.2 Describe Data Numerically

# %%
# obtain the shape of the dataframe
lipids.shape
# Out:
# (73, 1084)

# %% [markdown]
# There are 1084 columns showing the lipid concentrations for 1084 different lipid molecules. There are 73 rows the different samples taken for each control and experimental group.

# %% [markdown]
# Two features to investigate: lipid concentrations for lipid molecule Cer(d18:0_22:0+O) and lipid concentrations for lipid molecule Hex1Cer(t18:0_22:2).

# %% [markdown]
# Prediction for describe function:
#
# The count is expected to be 73 as there 73 different samples that were used and each sample has a concentration number for each of the lipid molecules. Looking at just the raw data below, it is expected that the Cer(d18:0_22:0+O) molecule will have a higher mean (average) than the Hex1Cer(t18:0_22:2) molecule.

# %%
lipids['Cer(d18:0_22:0+O)']
# Out:
# C0_01     70.662310
# C0_02     36.551808
# C0_03    102.089530
# C0_04     54.694195
# C0_05    233.437185
#             ...
# P7_09     50.503267
# P7_10    409.891665
# P7_11    252.541524
# P7_12     97.157215
# P7_13    130.795135
# Name: Cer(d18:0_22:0+O), Length: 73, dtype: float64

# %%
lipids['Hex1Cer(t18:0_22:2)']
# Out:
# C0_01     19.161914
# C0_02     23.618721
# C0_03     71.500766
# C0_04     38.805094
# C0_05    163.034066
#             ...
# P7_09     43.159210
# P7_10    301.779852
# P7_11    132.223529
# P7_12     54.399622
# P7_13     97.478317
# Name: Hex1Cer(t18:0_22:2), Length: 73, dtype: float64

# %%
# run the describe function the first lipid molecule
lipids['Cer(d18:0_22:0+O)'].describe()
# Out:
# count       73.000000
# mean       455.742970
# std       1768.769756
# min          0.628369
# 25%         35.219811
# 50%         67.251848
# 75%        167.581841
# max      14193.200830
# Name: Cer(d18:0_22:0+O), dtype: float64

# %%
# run the describe function for the second lipid molecule
lipids['Hex1Cer(t18:0_22:2)'].describe()
# Out:
# count       73.000000
# mean       382.726813
# std       2187.656201
# min          0.901671
# 25%         19.161914
# 50%         38.805094
# 75%        110.658051
# max      18646.239280
# Name: Hex1Cer(t18:0_22:2), dtype: float64

# %% [markdown]
# As expected, the count is 73 for the 73 different rows. Also, as predicted the average for the first lipid molecule is higher compared to the second lipid molecule. Both the mins are close but the max values are farther away from each other.

# %% [markdown]
# ### 3.3 Visualizations

# %% [markdown]
# Bar graphs would be the best way to present the lipid concentrations in each sample for the 2 different lipid molecules. The concentrations could be compared for both lipid molecules based on the bar heights. By comparing the different lipid concentrations, it can be observed which lipid molecule the PTEN affects the most.

# %%
# import seaborn
import seaborn as sns
sns.set_theme()

# %%
# make a bar graph showing the experimental group lipid concentrations for the first lipid molecule in each sample
sns.barplot(data = lipids, y = lipids['Cer(d18:0_22:0+O)'], x = lipids.index)
# Out:
# <Axes: xlabel='None', ylabel='Cer(d18:0_22:0+O)'>

# %% [markdown]
# As found with the describe function the max based on the graph is around 14,100. In the describe function, the max is 14193.200830. The min based on the graph is around 0. Based on the describe function, the min is 0.628369. There are 73 bars on the graph.

# %%
# make a bar graph showing the experimental group lipid concentrations for the second lipid molecule in each sample
f = sns.barplot(data = lipids, y = lipids['Hex1Cer(t18:0_22:2)'], x = lipids.index)

# %% [markdown]
# As found with the describe function the max based on the graph is around 18,500. In the describe function, the max is 18646.239280. The min based on the graph is around 0. Based on the describe function, the min is 0.901671. There are 73 bars on the graph.

# %% [markdown]
# From the graphs and describe function, it can be observed that there is a slightly higher effect on the Hex1Cer(t18:0_22:2) lipid molecule because the mean and the max are higher.

# %% [markdown]
# One of the hypothesis in the paper was that PTEN effects the lipid concentrations. When the control and experimental groups are compared on the graphs, the bars have slightly higher heights for the experimental groups compared to the control groups.
