# %% [markdown]
# # Project Part 2: Relate Research Questions, Data, and Figures

# %% [markdown]
# ## Section 1: Data and Research Questions

# %% [markdown]
# The following is a link to the study: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7797512/.
#
#
# The central nervous system controls many of the human body’s functions. One important part of
# the system includes the optic nerve that acts as a communication method to send visual images
# from the eye to the brain: an integral part of eyesight. The optic nerve can regenerate after
# damage to the nerve, however, the ability to regenerate is limited.
#
#
# The observations in the data set are the different samples that were collected. Each tissue optic nerve crush sample from mice is an observation. There are 74 observations or different samples that were collected from mice. This study was done on mice. One possible
# way to promote regeneration of the optic nerve is through phosphatase and ten homolog (PTEN)
# deletion. To test the hypothesis, mice were injected with either control (AAV-PLAP) or AAV-Cre
# (KO). Samples of the optic nerve crush were collected, and lipids were extracted and analyzed
# by liquid chromatography- mass spectrometry to find the concentration of lipids in those
# samples. There are two features for this dataset. One feature is the type of lipid molecule measured and the other feature is the lipid concentration found in each of the samples. These features tell us the lipid concentrations for each of the optic nerve crush samples that were collected and analyzed. In other words, the features measure the lipid concentration in each of our observations.
#
#
# The purpose of this study was to explore optic nerve regeneration and how to promote
# regeneration after an injury. The hypothesis was that the deletion of PTEN promotes regeneration
# of the optic nerve. PTEN is a major regulator in the PI3K/AKT signaling pathway. When PTEN dephosphorylates PIP3, the ability of regeneration is reduced. So, if PTEN is removed, it should promote regeneration. Lipids are also an important part of the same pathway as PIP3 is also a lipid. Changes in the lipid concentrations would reflect changes in the pathway which could help support the hypothesis that PTEN deletion can promote regeneration. Through the different lipid concentration collected from the samples, the
# concentrations for the control can be compared with the experimental group to determine if there
# are significant changes in lipids. If there are changes in the lipid concentrations, it can support
# that regeneration could be promoted by PTEN deletion.
#
#
# The paper is asking when PTEN is deleted, are there any changes in lipid concentration? If there are it could be associated with the promotion of regeneration. The paper only compares lipid concentrations between control and PTEN deletion groups. One other research question that could be asked using this data is which of the lipids measured are upregulated and which of the lipids measured are downregulated? By looking at the regulation of the specific lipids, it can provide insight into which lipids are important to regeneration promotion, specifically the lipids that are upregulated. This data can be useful to answer this question as it contains the different types of lipids and the concentrations, we can find the difference between the PTEN deletion group and control group lipid concentrations. A positive change would indicate upregulation and a negative change would indicate downregulation which would tell us which upregulated lipids are more important.

# %% [markdown]
# ### Points Lost

# %% [markdown]
# In this section, I lost points for not specifying what the samples were for in the observations. To fix this, I added in specifically that the observations are not just samples but the optic nerve crush samples from each mice.
#
# I also lost points for stating that there was only one feature which didn't make sense because different lipids were also being looked at. To make this clear, I added in that there are 2 features which are specified as the type of lipid measured and the concentration of that lipid in the control and PTEN deletion groups.
#
# Additionally, I had stated the hypothesis of the paper but didnt explain how the dataset would help investigate the hypothesis. What I added in to fix this was how PTEN deletion affects the specific pathway and why lipids can be used to tell if there is any affect of that deletion on optic nerve regeneration.
#
# Finally, the last thing in this section was that my proposed question was very similar to the paper's. What I did to make this different is specify that we could look at a different question and look at the upregulation and downregulation of the different lipids using the provided lipid concentrations.

# %% [markdown]
# ## Section 2: Data and Research Questions

# %% [markdown]
# ![image.png](attachment:7d6c56c3-4feb-4d6e-a73a-94091654a55d.png)
# Figure 1. Plot of variable importance in projection (VIP) scores
#
# The plots in the first figure was generated using the same lipid data as mentioned in section one.
# The x – axis shows the VIP scores for each of the lipids displayed on the y – axis. Plot A, on the
# left, displays the scores for the control groups at days 0, 7, and 14. Plot B, on the right, displays
# the scores for the experiment groups with PTEN deletion for days 0, 7, and 14.
#
# VIP scores in this paper and figure are used to show how strongly a lipid contributes to the difference between the groups (control and PTEN deletion). The higher a VIP score is, the stronger it is making an influence on the difference between the groups. In this case, days could also be counted as a feature as the different optic nerve tissue samples were taken and analyzed at 0, 7, and 14 days. Both plots have colored squares. Each column of squares is labeled with the day that the sample was analyzed. According to the legend, a high impact of the lipid on that group is represented by red and a lower impact is represented by blue.
#
# The authors chose to include this particular figure in the paper to show the difference in lipids
# with PTEN deletion. It can be observed from the plots that with the PTEN deletion, there are
# changes in the lipids which could support the hypothesis that PTEN deletion promotes optic
# nerve regeneration. It can be concluded that PTEN deletion has some effect on regeneration
# which is shown through the differences in the lipids when comparing the control to the
# experiment group. This is shown through the lipid VIP scores. The lipids with higher VIP scores show that they played a significant role in promoting regeneration. Therefore, the PTEN deletion changed the lipids in a way that increased the chances of regeneration since there were higher VIP scores of certain lipids.

# %% [markdown]
# ![image.png](attachment:6c2a2d04-9f29-4a39-8926-6c2e82db0226.png)
#
# Figure 2. Heatmap of the regeneration distances based on the changes in lipids
#
# The heatmap in this figure displays which lipid influenced further regeneration of the optic
# nerve. The row with the different colors at the very top represents the different classes or samples of
# controls at day 0, 7, and 14 and the experiment groups at 0, 7, and 14 days. On the right is the
# labeled rows with the different lipids. The darker reds represent the greatest positive change in
# distance and the darker blues represent the least change in distance of regeneration.
#
# Each row represents the specific type of lipid being analyzed and each column is the optic nerve crush sample that is analyzed. The intensity of the colors represent the concentration of that specific lipid in that specific sample. So, the higher concentrations are represented by red and the lower concentrations by blue.
#
# The authors chose to include this figure in the paper to show if the PTEN deletion affected how
# much regeneration occurred and which lipids were affected the most. Through this heatmap, it
# can be observed that with the PTEN deletion some lipids had a very big change compared to
# others and had the greatest distance difference in regeneration. This supports the hypothesis and
# it can be concluded that PTEN deletion promoted regeneration because of the significant change
# in the distance and lipids. This can be concluded looking at the figure as a whole. All the way to the left of the heatmap is the control group at 0 days and all the way to the right is the PTEN deletion group at 14 days. Looking at the colored squares we can tell that most of the lipids show an opposite effect with the PTEN deletion. Most of the one that were red for the control are now blue for the PTEN deletion group and vice versa.

# %% [markdown]
# One other figure that would be helpful to understand the lipid dataset would be a histogram. The
# x – axis would be the different lipid concentration ranges and the y – axis would be the count of
# how many lipids are within those ranges. The histogram would help to tell how many lipids have
# a significant change in concentration by looking at how many lipids are part of the higher value
# bins towards the right of the x – axis.
#
# ![image.png](attachment:f291d5ec-4b6a-494c-a365-03c0f788aeec.png)

# %% [markdown]
# ### Points Lost

# %% [markdown]
# First, I lost points in this section because the explanation of the figure was unclear. I added in what VIP scores meant for the figure if they are high versus low. I also added in what the colored squares mean to the right of the figure.
#
# I had stated a conclusion that we could draw from the figure, but it wasn't clear how we could reach that conclusion. I added in an explanation showing how the higher VIP scores can be used to draw the conclusion.
#
# For figure 2, again I didn't explain every part of the heatmap clearly. I added in extra explanations of what each row and column means and how we look at the different colors for each box.
#
# Like figure 1, I needed to show how the figure supports the conclusion. I added in how the opposite effect of the colored squares at the end support the conclusion.

# %% [markdown]
# ## Section 3: Data and Research Questions

# %% [markdown]
# Here is a link to the data file: mmc1 (2).xlsx
#
# There are 1085 rows and 74 columns in the dataset. The file relates to the paper through the lipid
# concentrations that are observed for each of the optic nerve samples. The data also contains the
# different lipids that were observed. Using the lipid data the control and experiment groups can be
# compared to see if PTEN deletion has any effect on optic nerve regeneration. The format of the
# data is different lipids in the first column and then other columns show one sample each. The
# rows represent the values for the lipid labeled for that row.
